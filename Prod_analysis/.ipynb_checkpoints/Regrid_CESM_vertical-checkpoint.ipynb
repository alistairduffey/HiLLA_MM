# %%
import xarray as xr
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cftime
import matplotlib
from tqdm import tqdm
#import xgcm
from xgcm import Grid

from config import path_archive

# %% [markdown]
# Converts CESM outputs on pressure levels, onto geopotential height levels (Z3), using the xgcm vertical regridding function.
#
# Code from here: https://xgcm.readthedocs.io/en/latest/transform.html#Realistic-Data-Example

# %%
def process_CE(ds):
    #ds = ds.sel(time=slice('2050', '2069')).groupby('time.month').mean(dim='time')
    ds = ds.mean('lon')
    ds = ds.rename({'lat':'latitude'})
    return ds

ds_HILLS_13_CE = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/SO4_burden/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.so4_a1a2a3c1c2c3_zm.203501-206912.nc')), 'time_bnds')
ds_HILLS_15_CE = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/SO4_burden/case04_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_15km_MAMJ_6Tg.001.cam.h0.so4_a1a2a3c1c2c3_zm.203501-206912.nc')), 'time_bnds')

ds_Z_CE_13 = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/Z3/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.Z3_zm.203501-206912.nc')), 'time_bnds')
ds_Z_CE_15 = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/Z3/case04_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_15km_MAMJ_6Tg.001.cam.h0.Z3_zm.203501-206912.nc')), 'time_bnds')


ds_HILLS_13_CE = xr.merge([ds_HILLS_13_CE, ds_Z_CE_13])
ds_HILLS_15_CE = xr.merge([ds_HILLS_15_CE, ds_Z_CE_15])

target_Z_levels = np.linspace(0, 30000, 100) # only need up to e.g. 30km

# %%
os.makedirs(path_archive+'/CESM_data/SO4_burdenZ/', exist_ok=True)

# %%
grid = Grid(ds_HILLS_13_CE, coords={'Z3': {'center': 'lev'},
                        },
                periodic=False
            )
ds_HILLS_13_CE_on_Z = grid.transform(ds_HILLS_13_CE.so4_a1a2a3c1c2c3, 'Z3', target_Z_levels, target_data=ds_HILLS_13_CE.Z3, method='linear')
ds_HILLS_13_CE_on_Z.to_netcdf(path_archive+'/CESM_data/SO4_burdenZ/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.so4_a1a2a3c1c2c3_zm_Z3.203501-206912.nc')
# Out:
# /home/users/a_duffey/.conda/envs/cmipv2/lib/python3.12/site-packages/xgcm/grid.py:989: FutureWarning: From version 0.8.0 the Axis computation methods will be removed, in favour of using the Grid computation methods instead. i.e. use `Grid.transform` instead of `Axis.transform`
#   warnings.warn(

# %%
grid = Grid(ds_HILLS_15_CE, coords={'Z3': {'center': 'lev'},
                        },
                periodic=False
            )
ds_HILLS_15_CE_on_Z = grid.transform(ds_HILLS_15_CE.so4_a1a2a3c1c2c3, 'Z3', target_Z_levels, target_data=ds_HILLS_15_CE.Z3, method='linear')
ds_HILLS_15_CE_on_Z.to_netcdf(path_archive+'/CESM_data/SO4_burdenZ/case04_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_15km_MAMJ_6Tg.001.cam.h0.so4_a1a2a3c1c2c3_zm_Z3.203501-206912.nc')
# Out:
# /home/users/a_duffey/.conda/envs/cmipv2/lib/python3.12/site-packages/xgcm/grid.py:989: FutureWarning: From version 0.8.0 the Axis computation methods will be removed, in favour of using the Grid computation methods instead. i.e. use `Grid.transform` instead of `Axis.transform`
#   warnings.warn(

# %%
## plot to check

ds_HILLS_15_CE_on_Z.isel(time=-1).plot()

# %%
ds_HILLS_13_CE_on_Z.isel(time=-1).plot()

# %%
ds_Z_CE_13
# Out:
# <xarray.Dataset> Size: 23MB
# Dimensions:    (time: 420, bnds: 2, latitude: 192, lev: 70)
# Coordinates:
#   * time       (time) object 3kB 2035-02-01 00:00:00 ... 2070-01-01 00:00:00
#   * latitude   (latitude) float64 2kB -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * lev        (lev) float64 560B 5.96e-06 9.827e-06 1.62e-05 ... 976.3 992.6
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object 7kB 2035-01-01 00:00:00 ... 2070-01-01 00:...
#     lev_bnds   (lev, bnds) float64 1kB 5.96e-06 9.827e-06 ... 992.6 993.6
#     Z3         (time, lev, latitude) float32 23MB 1.423e+05 1.423e+05 ... 55.14

# %%
ds_HILLS_15_CE
# Out:
# <xarray.Dataset> Size: 23MB
# Dimensions:       (latitude: 192, zlon: 1, nbnd: 2, lev: 70, ilev: 71, time: 420)
# Coordinates:
#   * latitude      (latitude) float64 2kB -90.0 -89.06 -88.12 ... 89.06 90.0
#   * zlon          (zlon) float64 8B 0.0
#   * lev           (lev) float64 560B 5.96e-06 9.827e-06 1.62e-05 ... 976.3 992.6
#   * ilev          (ilev) float64 568B 4.5e-06 7.42e-06 1.223e-05 ... 985.1 1e+03
#   * time          (time) object 3kB 2035-02-01 00:00:00 ... 2070-01-01 00:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/27)
#     zlon_bnds     (zlon, nbnd) float64 16B 0.0 358.8
#     gw            (latitude) float64 2kB 3.382e-05 0.0002705 ... 3.382e-05
#     hyam          (lev) float64 560B 5.96e-09 9.827e-09 ... 0.001989 0.0
#     hybm          (lev) float64 560B 0.0 0.0 0.0 0.0 ... 0.9512 0.9743 0.9926
#     P0            float64 8B 1e+05
#     hyai          (ilev) float64 568B 4.5e-09 7.42e-09 1.223e-08 ... 0.0 0.0
#     ...            ...
# ...

# %%
### now repeat for the O3 data: 

def process_CE(ds):
    #ds = ds.sel(time=slice('2050', '2069')).groupby('time.month').mean(dim='time')
    ds = ds.mean('lon')
    ds = ds.rename({'lat':'latitude'})
    return ds

ds_HILLS_13_CE = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/Ozone/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.O3.203501-206912.nc')), 'time_bnds')
ds_HILLS_15_CE = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/Ozone/case04_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_15km_MAMJ_6Tg.001.cam.h0.O3.203501-206912.nc')), 'time_bnds')

ds_Z_CE_13 = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/Z3/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.Z3_zm.203501-206912.nc')), 'time_bnds')
ds_Z_CE_15 = set_time_to_center_of_bounds(process_CE(xr.open_dataset(path_archive+'/CESM_data/Z3/case04_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_15km_MAMJ_6Tg.001.cam.h0.Z3_zm.203501-206912.nc')), 'time_bnds')


ds_HILLS_13_CE = xr.merge([ds_HILLS_13_CE, ds_Z_CE_13], compat='override') # unclear why override is needed here (conflicted time_bnds but they look fine to me.. 
ds_HILLS_15_CE = xr.merge([ds_HILLS_15_CE, ds_Z_CE_15], compat='override')

target_Z_levels = np.linspace(0, 30000, 100) # only need up to e.g. 30km

os.makedirs(path_archive+'/CESM_data/Ozone_Z/', exist_ok=True)

grid = Grid(ds_HILLS_13_CE, coords={'Z3': {'center': 'lev'},
                        },
                periodic=False
            )
ds_HILLS_13_CE_on_Z = grid.transform(ds_HILLS_13_CE.O3, 'Z3', target_Z_levels, target_data=ds_HILLS_13_CE.Z3, method='linear')
ds_HILLS_13_CE_on_Z.to_netcdf(path_archive+'/CESM_data/Ozone_Z/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.O3_Z3.203501-206912.nc')

grid = Grid(ds_HILLS_15_CE, coords={'Z3': {'center': 'lev'},
                        },
                periodic=False
            )
ds_HILLS_15_CE_on_Z = grid.transform(ds_HILLS_15_CE.O3, 'Z3', target_Z_levels, target_data=ds_HILLS_15_CE.Z3, method='linear')
ds_HILLS_15_CE_on_Z.to_netcdf(path_archive+'/CESM_data/Ozone_Z/case04_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_15km_MAMJ_6Tg.001.cam.h0.O3_Z3.203501-206912.nc')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 27
#      21 os.makedirs(path_archive+'/CESM_data/Ozone_Z/', exist_ok=True)
#      23 grid = Grid(ds_HILLS_13_CE, coords={'Z3': {'center': 'lev'},
#      24                         },
#      25                 periodic=False
#      26             )
# ---> 27 ds_HILLS_13_CE_on_Z = grid.transform(ds_HILLS_13_CE.so4_a1a2a3c1c2c3, 'Z3', target_Z_levels, target_data=ds_HILLS_13_CE.Z3, method='linear')
#      28 ds_HILLS_13_CE_on_Z.to_netcdf(path_archive+'/CESM_data/Ozone_Z/case01_b.e21.BWSSP245cmip6.f09_g17.polar_SAI_sensitivity_60NS_13km_MAMJ_6Tg.001.cam.h0.O3_Z3.203501-206912.nc')
#      30 grid = Grid(ds_HILLS_15_CE, coords={'Z3': {'center': 'lev'},
#      31                         },
#      32                 periodic=False
#      33             )
#
# ...

# %%
## DEV:
## also want to find the approx. vertical height of the CESM injection locations:
vals_13km = []
for t in ds_HILLS_13_CE.time.values:
    test = ds_HILLS_13_CE.sel(latitude=60, method='nearest').sel(time=t)  
    abs_diff_data = np.abs(test.Z3 - 13000)
    closest_indices_dict = abs_diff_data.argmin(...)
    vals_13km.append(test.isel(closest_indices_dict).Z3.item())

plt.plot(vals_13km)
